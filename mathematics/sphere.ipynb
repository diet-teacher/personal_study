# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
bucket_width, bucket_height = 1, 2
arm_length = 5
boom_length = 5

vec_start_x, vec_start_y, vec_start_z = 0,0,0
theta_horizontal = -15
theta_vertical = -20

vec_hrz_x = boom_length * np.sin(np.deg2rad(theta_horizontal))
vec_hrz_y = boom_length * np.cos(np.deg2rad(theta_horizontal))
vec_end_z = boom_length * np.sin(np.deg2rad(theta_vertical))

vec_end_x = boom_length * np.sin(np.deg2rad(theta_horizontal))
vec_end_y = boom_length * np.cos(np.deg2rad(theta_horizontal))






fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlim(-15, 15)
ax.set_ylim(-15, 15)
ax.set_zlim(-15, 15)

ax.set_xticks([-15, -12.5, -10, -7.5, -5, -2.5, 0, 2.5, 5, 7.5, 10, 12.5, 15])
ax.set_yticks([-15, -12.5, -10, -7.5, -5, -2.5, 0, 2.5, 5, 7.5, 10, 12.5, 15])
ax.set_zticks([-15, -12.5, -10, -7.5, -5, -2.5, 0, 2.5, 5, 7.5, 10, 12.5, 15])
ax.plot([0, vec_end_x], [0, vec_end_y], [0, vec_end_z], linewidth=3, color='green')
# ax.plot([0, 0], [boom_length, boom_length+arm_length], [0, 0], linewidth=3, color='green')
# [VecStart_x[i], VecEnd_x[i]], [VecStart_y[i],VecEnd_y[i]],zs=[VecStart_z[i],VecEnd_z[i]])

plt.tight_layout()
plt.show()

print("vec_hrz_x, vec_hrz_y, vec_end_z = ", vec_hrz_x, vec_hrz_y, vec_end_z)
# Out:
# vec_hrz_x, vec_hrz_y, vec_end_z =  -1.2940952255126037 4.8296291314453415 -1.7101007166283435
